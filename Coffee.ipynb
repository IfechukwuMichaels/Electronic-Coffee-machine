# %%
print("Hello, Welcome to my coffee machine!")

# %%
MENU = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "coffee": 18,
        },
        "cost": 1.5,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2.5,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3.0,
    }
}

resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}

# %%
#initializing variables
water_needed_espresso = MENU["espresso"]["ingredients"]["water"]
water_needed_latte = MENU["latte"]["ingredients"]["water"]
water_needed_cappuccino = MENU["cappuccino"]["ingredients"]["water"]

coffee_needed_espresso = MENU["espresso"]["ingredients"]["coffee"]
coffee_needed_latte = MENU["latte"]["ingredients"]["coffee"]
coffee_needed_cappuccino = MENU["cappuccino"]["ingredients"]["coffee"]

milk_needed_latte = MENU["latte"]["ingredients"]["milk"]
milk_needed_cappuccino = MENU["cappuccino"]["ingredients"]["milk"]

#cost_espresso = MENU["espresso"]["cost"]
#cost_latte = MENU["latte"]["cost"]
#cost_cappuccino = MENU["cappuccino"]["cost"]

resources_water = resources["water"]
resources_milk = resources["milk"]
resources_coffee = resources["coffee"]

money = 0

#resources_water = 300
#resources_milk = 200
#resources_coffee = 100

# %%
#check resources to ensure they are sufficient for making the order
def check_resources_espresso():
    global possible
    global water_needed_espresso
    global coffee_needed_espresso
    global resources_water
    global resources_coffee
    global money
    cost_espresso = MENU["espresso"]["cost"]
    
    if resources_water < water_needed_espresso:
        print ("sorry there is not enough water")
        #possible = False

    elif resources_coffee < coffee_needed_espresso:
        print ("sorry there is not enough coffee")
        #possible = False

    elif resources_water < water_needed_espresso and resources_coffee < coffee_needed_espresso:
        print ("sorry there is not enough water and coffee")
        #possible = False
    
    else:
        if resources_water > water_needed_espresso and resources_coffee > coffee_needed_espresso:
        #possible = True
            print("Please insert coins.")
            insert_quarters = int(input("How many quarters?: ").lower())
            amount_quarters = insert_quarters * 0.25

            insert_dimes = int(input("How many dimes?: ").lower())
            amount_dimes = insert_dimes * 0.10

            insert_nickles = int(input("How many nickles?: ").lower())
            amount_nickles = insert_nickles * 0.05

            insert_pennies = int(input("How many pennies?: ").lower())
            amount_pennies = insert_pennies * 0.01

            total_amount = amount_quarters + amount_dimes + amount_nickles + amount_pennies
            
            if total_amount < cost_espresso:
                print ("sorry that's not enough money. Money refunded")
                #possible = False
                
            else:
                change_espresso = total_amount - cost_espresso
                print(f"Here is ${change_espresso} change")
                print("Here is your espresso. Enjoy!")
                
                resources_water -= water_needed_espresso 
                resources_coffee -= coffee_needed_espresso
                money += cost_espresso

# %%
#check resources to ensure they are sufficient for making the order
      
    #if ask == "latte":
def check_resources_latte():
    global possible
    global water_needed_latte
    global milk_needed_latte
    global coffee_needed_latte
    global money
    
    global resources_water
    global resources_milk
    global resources_coffee
    
    cost_latte = MENU["latte"]["cost"]
                
    if resources_water < water_needed_latte:
        print ("sorry there is not enough water")
        #possible = False
    elif resources_water < water_needed_latte and resources_milk < milk_needed_latte:
        print ("sorry there is not enough water and milk")
        #possible = False

    elif resources_milk < milk_needed_latte and resources_coffee < coffee_needed_latte:
        print ("sorry there is not enough milk and coffee")
        #possible = False

    elif resources_coffee < coffee_needed_latte and resources_water < water_needed_latte:
        print ("sorry there is not enough water and coffee")
        #possible = False

    elif resources_water < water_needed_latte and resources_milk < milk_needed_latte and resources_coffee < coffee_needed_latte:
        print ("sorry there is not enough water, and milk and coffee")
        #possible = False
        
    else:
        if resources_water > water_needed_latte and resources_milk > milk_needed_latte and resources_coffee > coffee_needed_latte:
            
            print("Please insert coins.")
            insert_quarters = int(input("How many quarters?: ").lower())
            amount_quarters = insert_quarters * 0.25

            insert_dimes = int(input("How many dimes?: ").lower())
            amount_dimes = insert_dimes * 0.10

            insert_nickles = int(input("How many nickles?: ").lower())
            amount_nickles = insert_nickles * 0.05

            insert_pennies = int(input("How many pennies?: ").lower())
            amount_pennies = insert_pennies * 0.01

            total_amount = amount_quarters + amount_dimes + amount_nickles + amount_pennies
            
            if total_amount < cost_latte:
                print ("sorry that's not enough money. Money refunded")
                #possible = False
            else:
                change_latte = total_amount - cost_latte
                print(f"Here is ${change_latte} change")
                print("Here is your latte. Enjoy!")
                resources_water -= water_needed_latte
                resources_milk -= milk_needed_latte 
                resources_coffee -= coffee_needed_latte
                money += cost_latte

# %%
#check resources to ensure they are sufficient for making the order

def check_resources_cappuccino():
    
    global possible
    global water_needed_cappuccino
    global milk_needed_cappuccino
    global coffee_needed_cappuccino
    
    global resources_water
    global resources_milk
    global resources_coffee
    global money

    cost_cappuccino = MENU["cappuccino"]["cost"]

    if resources_water < water_needed_cappuccino:
        print ("sorry there is not enough water")
        #possible = False
    elif resources_water < water_needed_cappuccino and resources_milk < milk_needed_cappuccino:
        print ("sorry there is not enough water and milk")
        #possible = False

    elif resources_milk < milk_needed_cappuccino and resources_coffee < coffee_needed_cappuccino:
        print ("sorry there is not enough milk and coffee")
        #possible = False

    elif resources_coffee < coffee_needed_cappuccino and resources_water < water_needed_cappuccino:
        print ("sorry there is not enough water and coffee")
        #possible = False

    elif resources_water < water_needed_cappuccino and resources_milk < milk_needed_cappuccino and resources_coffee < coffee_needed_cappuccino:
        print ("sorry there is not enough water, and milk and coffee")
        #possible = False

    else:

        #if resources_water > water_needed_cappuccino and resources_milk > milk_needed_cappuccino and resources_coffee > coffee_needed_cappuccino:

        print("Please insert coins.")
        insert_quarters = int(input("How many quarters?: ").lower())
        amount_quarters = insert_quarters * 0.25

        insert_dimes = int(input("How many dimes?: ").lower())
        amount_dimes = insert_dimes * 0.10

        insert_nickles = int(input("How many nickles?: ").lower())
        amount_nickles = insert_nickles * 0.05

        insert_pennies = int(input("How many pennies?: ").lower())
        amount_pennies = insert_pennies * 0.01

        total_amount = amount_quarters + amount_dimes + amount_nickles + amount_pennies

        if total_amount < cost_cappuccino:
            print ("sorry that's not enough money. Money refunded")

        #another = input("Would you like another drink? 'yes' or 'no': ").lower()
        #if another == "no":
            #print("Good bye, have a nice day!")
            #possible = False
        else:
            change_cappuccino = total_amount - cost_cappuccino
            print(f"Here is ${change_cappuccino} change")
            print("Here is your cappuccino. Enjoy!")
            resources_water -= water_needed_cappuccino
            resources_milk -= milk_needed_cappuccino 
            resources_coffee -= coffee_needed_cappuccino
            money += cost_cappuccino

# %%
def play():
    
    global money
    global resources_milk
    global resources_coffee
    global resources_water
    
    global water_needed_espresso
    global coffee_needed_espresso
       
    global water_needed_latte
    global milk_needed_latte
    global coffee_needed_latte

    global water_needed_cappuccino
    global milk_needed_cappuccino
    global coffee_needed_cappuccino
    
    global money
    global possible
    
    while possible == True: 
        ask = input("What would you like? (select 'E' for Espresso/ 'L' for latte/ 'C' for cappuccino): ").lower()

        if ask == "report":
            
            print(f"water: {resources_water} ml")
            print(f"milk: {resources_milk} g")
            print(f"coffee: {resources_coffee} ml")
            print(f"money: ${money}")
            
            another = input("Would you like another drink? 'yes' or 'no': ").lower()
            if another == "no":
                print("Good bye, have a nice day!")
                possible = False
            else:
                if another == "yes":
                    possible = True

        elif ask == "e":
            check_resources_espresso()
            another = input("Would you like another drink? 'yes' or 'no': ").lower()
            if another == "no":
                print("Good bye, have a nice day!")
                possible = False
            else:
                if another == "yes":
                    possible = True

        elif ask == "l":
            check_resources_latte()
            another = input("Would you like another drink? 'yes' or 'no': ").lower()
            if another == "no":
                print("Good bye, have a nice day!")
                possible = False
            else:
                if another == "yes":
                    possible = True
        
        elif ask == "c":
            check_resources_cappuccino()

            another = input("Would you like another drink? 'yes' or 'no': ").lower()
            if another == "no":
                print("Good bye, have a nice day!")
                possible = False
            else:
                if another == "yes":
                    possible = True

# %%
possible = True
play()
